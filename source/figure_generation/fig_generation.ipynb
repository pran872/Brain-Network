# %%
import matplotlib.pyplot as plt

# %%
training_data = [10, 25, 50, 100]
neurozoom_accuracy = [79.13, 87.34, 90.99, 94.49]
neurofocus_accuracy = [67.96, 81.10, 87.8, 91.72]
resnet_accuracy = [71.35, 84.38, 88.5, 92.65]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(training_data, neurozoom_accuracy, "-s")
plt.plot(training_data, neurofocus_accuracy, "-s")
plt.plot(training_data, resnet_accuracy, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="lower right")
plt.tight_layout()
# plt.savefig("cifar_10_acc_samp_eff.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/1673850923.py:26: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(training_data, neurozoom_accuracy, "-s")

# %%
training_data = [10, 25, 50, 100]
neurozoom_accuracy_scratch = [3.74, 14.43, 40.51, 63.24]
neurozoom_accuracy_pretrained = [2.26, 44.38, 62.84, 71.63]
resnet_accuracy_scratch = [7.6, 16.88, 29.81, 45.17]
resnet_accuracy_pretrained = [46.33, 62.52, 69.06, 73.54]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(training_data, neurozoom_accuracy_scratch, "-s")
plt.plot(training_data, resnet_accuracy_scratch, "-s", color="green")
# plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
# plt.plot(training_data, resnet_accuracy_pretrained, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch", "NeuroZoom Pretrained", "ResNet-18 Pretrained"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_acc_samp_eff.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/4132807468.py:27: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(training_data, neurozoom_accuracy_scratch, "-s")

# %%
training_data = ["NeuroZoom", "NeuroFocus", "ResNet-18"]
acc = [94.49, 91.72, 92.65]
# neurozoom_accuracy = [79.13, 87.34, 90.99, 94.49]
# neurofocus_accuracy = [67.96, 81.10, 87.8, 91.72]
# resnet_accuracy = [71.35, 84.38, 88.5, 92.65]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.bar(training_data, acc)
# plt.bar(training_data, resnet_accuracy_scratch, "-s")
# plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
# plt.plot(training_data, resnet_accuracy_pretrained, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
# plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch", "NeuroZoom Pretrained", "ResNet-18 Pretrained"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_acc_samp_eff.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/2506219649.py:25: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.bar(training_data, acc)

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [50.16, 47.03, 42.74, 35.68]
neurofocus = [52.15, 47.37, 42.50, 36.48]
resnet = [45.21, 42.21, 39.53, 34.43]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(epsilon, neurozoom, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/263645604.py:24: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(epsilon, neurozoom, "-s")

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [8.72, 2.68, 1.76, 1.46]
neurofocus = []
resnet_scratch = [7.34, 2.83, 1.21, 0.57]

neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, resnet_scratch, "-s", color="g")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/2093835706.py:27: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(epsilon, neurozoom_scratch, "-s")

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [33.98, 11.31, 7.86, 5.48]
neurofocus = [39.05, 12.48, 8.91, 6.02]
resnet_scratch = [32.55, 12.9, 10.95, 9.39]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_scratch, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_pgd.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/1781920642.py:27: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(epsilon, neurozoom_scratch, "-s")

# %%
# import matplotlib.pyplot as plt

# epsilon = [0.01, 0.05, 0.1, 0.2]
# neurozoom_scratch = [0.91,]
# neurofocus = []
# resnet_scratch = [7.34, 2.83, 1.21, 0.57]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "serif",
#     "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
#     "axes.labelsize": 14,
#     "font.size": 14,
#     "legend.fontsize": 12,
#     "xtick.labelsize": 12,
#     "ytick.labelsize": 12,
#     "axes.linewidth": 1,
#     "lines.markersize": 6,
#     "lines.linewidth": 2,
#     "legend.frameon": False,
#     "legend.handlelength": 2,
# })

# plt.plot(epsilon, neurozoom_scratch, "-s")
# plt.plot(epsilon, resnet_scratch, "-s")
# # plt.plot(epsilon, neurozoom_pretrained, "-s")
# # plt.plot(epsilon, resnet_pretrained, "-s")
# plt.xlabel(r"Epsilon")
# plt.ylabel("Classification Accuracy (%)")
# plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch"], loc="upper right")
# plt.tight_layout()
# # plt.savefig("stanford_dogs_fgsm.pdf", dpi=300)
# plt.show()

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [51.11, 50.84, 48.69, 42.7]
neurofocus = [53.46, 52.92, 51.03, 46.63]
resnet_scratch = [45.91, 45.70, 44.30, 40.28]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_scratch, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="upper right")
plt.tight_layout()
plt.savefig("cifar10_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/705481803.py:27: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(epsilon, neurozoom_scratch, "-s")

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [14.84, 14.49, 12.41, 8]
# neurofocus = [53.46, 52.92, 51.03, 46.63]
resnet_scratch = [9.48, 9.62, 9.39, 8.62]

neurozoom_pretrained = [20.48, 19.58, 16.25, 10.17]
resnet_pretrained = [18.33, 17.41, 14.42, 9.55]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_scratch, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"])
plt.tight_layout()
plt.savefig("stanford_dogs_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_39032/3797887196.py:27: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(epsilon, neurozoom_scratch, "-s")
