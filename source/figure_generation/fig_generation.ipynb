# %%
import matplotlib.pyplot as plt

# %%
training_data = [10, 25, 50, 100]
resnet_accuracy = [74.19, 85.09, 90.37, 93.58]
neurozoom_accuracy = [79.06, 87.23, 91.38, 94.46]
neurofocus_accuracy = [77.34, 86.29, 90.45, 93.59]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([70, 96])
plt.plot(training_data, neurozoom_accuracy, "-s")
plt.plot(training_data, neurofocus_accuracy, "-s")
plt.plot(training_data, resnet_accuracy, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="lower right")
plt.tight_layout()
# plt.savefig("cifar_10_acc_samp_eff.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2762815989.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([70, 96])

# %%
training_data = [10, 25, 50, 100]
resnet_accuracy_pretrained = [84.42, 90.51, 93.25, 95.08]
neurozoom_accuracy_pretrained = [87.36, 91.72, 93.70, 94.14]
neurofocus_accuracy_pretrained = [77.51, 85.38, 88.94, 86.62]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([70, 96])
plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
plt.plot(training_data, neurofocus_accuracy_pretrained, "-s")
plt.plot(training_data, resnet_accuracy_pretrained, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="lower right")
plt.tight_layout()
# plt.savefig("cifar_10_acc_samp_eff_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1685751002.py:21: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([70, 96])

# %%
# training_data = [10, 25, 50, 100]
# resnet_accuracy_pretrained = [84.42, 90.51, 93.25, 95.08]
# neurozoom_accuracy_pretrained = [87.36, 91.72, 93.70, 94.14]
# neurofocus_accuracy_pretrained = [77.51, 85.38, 88.94, 86.62]
# resnet_accuracy = [74.19, 85.09, 90.37, 93.58]
# neurozoom_accuracy = [79.06, 87.23, 91.38, 94.46]
# neurofocus_accuracy = [77.34, 86.29, 90.45, 93.59]

# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "serif",
#     "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
#     "axes.labelsize": 14,
#     "font.size": 14,
#     "legend.fontsize": 12,
#     "xtick.labelsize": 12,
#     "ytick.labelsize": 12,
#     "axes.linewidth": 1,
#     "lines.markersize": 6,
#     "lines.linewidth": 2,
#     "legend.frameon": False,
#     "legend.handlelength": 2,
# })

# plt.plot(training_data, neurozoom_accuracy, "-s", color='C0')
# plt.plot(training_data, neurozoom_accuracy_pretrained, "--s", color='C0')
# plt.plot(training_data, neurofocus_accuracy, "-s", color='C1')
# plt.plot(training_data, neurofocus_accuracy_pretrained, "--s", color='C1')
# plt.plot(training_data, resnet_accuracy, "-s", color='C2')
# plt.plot(training_data, resnet_accuracy_pretrained, "--s", color='C2')
# plt.xlabel(r"% of Training Data")
# plt.ylabel("Classification Accuracy (%)")
# plt.legend(["NeuroZoom", "NeuroFocus", "ResNet-18"], loc="lower right")
# plt.tight_layout()
# # plt.savefig("cifar_10_acc_samp_eff_pretrained.pdf", dpi=300)
# plt.show()

# %%
training_data = [10, 25, 50, 100]
neurozoom_accuracy = [3.74, 14.43, 40.51, 63.24]
neurofocus_accuracy = [3.07, 11.72, 40, 62.21] # 40 is not true!!!!
resnet_accuracy = [7.6, 16.88, 29.81, 45.17]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([0, 80])
plt.plot(training_data, neurozoom_accuracy, "-s")
plt.plot(training_data, neurofocus_accuracy, "-s")
plt.plot(training_data, resnet_accuracy, "-s", color="green")
# plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
# plt.plot(training_data, resnet_accuracy_pretrained, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "ResNet-18 Scratch"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_acc_samp_eff.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2777102920.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 80])

# %%
training_data = [10, 25, 50, 100]
neurozoom_accuracy_pretrained = [2.26, 44.38, 62.84, 71.63]
neurofocus_accuracy_pretrained = [2.81, 44.31, 60, 71.13] #60 is not real!!
resnet_accuracy_pretrained = [46.33, 62.52, 69.06, 73.54]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 80])
plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
plt.plot(training_data, neurofocus_accuracy_pretrained, "-s")
plt.plot(training_data, resnet_accuracy_pretrained, "-s", color="green")
# plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
# plt.plot(training_data, resnet_accuracy_pretrained, "-s")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "ResNet-18 Pretrained"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_acc_samp_eff_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1628792334.py:21: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 80])

# %%
# training_data = ["NeuroZoom", "NeuroFocus", "ResNet-18"]
# acc = [94.49, 91.72, 92.65]
# # neurozoom_accuracy = [79.13, 87.34, 90.99, 94.49]
# # neurofocus_accuracy = [67.96, 81.10, 87.8, 91.72]
# # resnet_accuracy = [71.35, 84.38, 88.5, 92.65]

# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "serif",
#     "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
#     "axes.labelsize": 14,
#     "font.size": 14,
#     "legend.fontsize": 12,
#     "xtick.labelsize": 12,
#     "ytick.labelsize": 12,
#     "axes.linewidth": 1,
#     "lines.markersize": 6,
#     "lines.linewidth": 2,
#     "legend.frameon": False,
#     "legend.handlelength": 2,
# })

# plt.bar(training_data, acc)
# # plt.bar(training_data, resnet_accuracy_scratch, "-s")
# # plt.plot(training_data, neurozoom_accuracy_pretrained, "-s")
# # plt.plot(training_data, resnet_accuracy_pretrained, "-s")
# plt.xlabel(r"% of Training Data")
# plt.ylabel("Classification Accuracy (%)")
# # plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch", "NeuroZoom Pretrained", "ResNet-18 Pretrained"], loc="lower right")
# plt.tight_layout()
# # plt.savefig("stanford_dogs_acc_samp_eff.pdf", dpi=300)
# plt.show()

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [56.04, 54.40, 50.88, 43.17]
neurofocus = [57.67, 55.92, 53.02, 47.44]
resnet = [53.02, 50.66, 47.70, 40.95]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([15, 65])
plt.plot(epsilon, neurozoom, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "ResNet-18 Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2796598008.py:21: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([15, 65])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_pretrained = [60.70, 53.91, 48.21, 38.87]
neurofocus_pretrained = [49.81, 36.21, 26.55, 18.22]
resnet_pretrained = [61.09, 58.21, 53.19, 42.57]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([15, 65])
plt.plot(epsilon, neurozoom_pretrained, "-s")
plt.plot(epsilon, neurofocus_pretrained, "-s")
plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "ResNet-18 Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_fgsm_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1540998153.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([15, 65])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [8.72, 2.68, 1.76, 1.46]
neurofocus = []
resnet_scratch = [7.34, 2.83, 1.21, 0.57]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 14])
plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, resnet_scratch, "-s", color="g")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "ResNet-18 Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1823815353.py:21: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 14])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]

neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([0, 14])
plt.plot(epsilon, neurozoom_pretrained, "-s")
plt.plot(epsilon, resnet_pretrained, "-s", color="g")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "ResNet-18 Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_fgsm_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2334404071.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 14])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [36.71, 14.99, 11.66, 8.39]
neurofocus = [41.72, 18.54, 14.92, 11.95]
resnet_scratch = [38.81, 19.73, 17.32, 14.66]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([0, 45])
plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_scratch, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "ResNet-18 Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_pgd.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1761656401.py:25: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 45])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_pretrained = [40.89, 10.46, 6.96, 4.30]
neurofocus = [41.31, 13.38, 8.11, 5.07]
resnet_pretrained = [43.64, 21.58, 18.48, 14.26]


plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([0, 45])
plt.plot(epsilon, neurozoom_pretrained, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_pretrained, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "ResNet-18 Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_pgd_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/735839244.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 45])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [56.30, 55.29, 52.72, 45.93]
neurofocus = [58.21, 57.82, 56.59, 51.57]
resnet_scratch = [53.68, 53.35, 51.92, 46.36]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([45, 65])
plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_scratch, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "ResNet-18 Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1792352958.py:25: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([45, 65])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_pretrained = [62.54, 61.89, 57.58, 47.36]
neurofocus = [54.15, 53.85, 52.72, 48.97]
resnet_pretrained = [61.62, 60.57, 57.33, 47.17]

# neurozoom_pretrained = [12.01, 3.60, 2.68, 2.25]
# resnet_pretrained = [13.16, 5.57, 3.62, 2.47]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([45, 65])
plt.plot(epsilon, neurozoom_pretrained, "-s")
plt.plot(epsilon, neurofocus, "-s")
plt.plot(epsilon, resnet_pretrained, "-s")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "ResNet-18 Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_gaussian_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/1640867698.py:24: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([45, 65])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom_scratch = [14.84, 14.49, 12.41, 8]
# neurofocus = [53.46, 52.92, 51.03, 46.63]
resnet_scratch = [9.48, 9.62, 9.39, 8.62]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([8, 21])
plt.plot(epsilon, neurozoom_scratch, "-s")
plt.plot(epsilon, resnet_scratch, "-s", color="Green")
# plt.plot(epsilon, neurozoom_pretrained, "-s")
# plt.plot(epsilon, resnet_pretrained, "-s")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch","ResNet-18 Scratch"])
plt.tight_layout()
# plt.savefig("stanford_dogs_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2695654812.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([8, 21])

# %%
epsilon = [0.01, 0.05, 0.1, 0.2]

neurozoom_pretrained = [20.48, 19.58, 16.25, 10.17]
resnet_pretrained = [18.33, 17.41, 14.42, 9.55]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})

plt.ylim([8, 21])
plt.plot(epsilon, neurozoom_pretrained, "-s")
plt.plot(epsilon, resnet_pretrained, "-s", color="green")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "ResNet-18 Pretrained"])
plt.tight_layout()
# plt.savefig("stanford_dogs_gaussian_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2058394834.py:22: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([8, 21])

# %% [markdown]
# # Ablation

# %%
# Ablation on CIFAR 10

training_data = [10, 25, 50, 100]
neurozoom = [79.06, 87.23, 91.38, 94.46]
neurofocus = [77.34, 86.29, 90.45, 93.59]
no_zoom = [79.57, 87.52, 91.31, 94.32]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([75, 95])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "No Zoom Scratch"], loc="lower right")
plt.tight_layout()
# plt.savefig("cifar10_no_zoom.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2671498161.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([75, 95])

# %%
# Ablation on CIFAR 10

training_data = [10, 25, 50, 100]
neurozoom_pretrained = [87.36, 91.72, 93.70, 94.14]
neurofocus_pretrained = [77.51, 85.38, 88.94, 86.62]
no_zoom_pretrained = [87.34, 76.56, 94.52, 80.65]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([75, 95])
plt.plot(training_data, neurozoom_pretrained, "-s")
plt.plot(training_data, neurofocus_pretrained, "-s")
plt.plot(training_data, no_zoom_pretrained, "-s", color="C3")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "No Zoom Pretrained"])
plt.tight_layout()
# plt.savefig("cifar10_no_zoom_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/2066860549.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([75, 95])

# %%
# Ablation on Stanford Dogs

training_data = [10, 25, 50, 100]
neurozoom = [3.74, 14.43, 40.51, 63.24]
neurofocus = [3.07, 11.72, 40, 62.21] # 40 is not true!!!!
no_zoom = [4.76, 12.87, 50, 62.58] # 50 is not true!!!

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 75])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "No Zoom Scratch"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/4258387848.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 75])

# %%
# Ablation on Stanford dogs

training_data = [10, 25, 50, 100]
neurozoom_pretrained = [2.26, 44.38, 62.84, 71.63]
neurofocus_pretrained = [2.81, 44.31, 60, 71.13] #60 is not real!!
no_zoom_pretrained = [1.75, 41.70, 55, 71.31] # 55 is not real!!

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 75])
plt.plot(training_data, neurozoom_pretrained, "-s")
plt.plot(training_data, neurofocus_pretrained, "-s")
plt.plot(training_data, no_zoom_pretrained, "-s", color="C3")
plt.xlabel(r"% of Training Data")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "No Zoom Pretrained"], loc="lower right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/3976427504.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 75])

# %%
# Ablation on CIFAR 10 - FGSM

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [56.04, 54.40, 50.88, 43.17]
neurofocus = [57.67, 55.92, 53.02, 47.44]
no_zoom = [54.41, 53.11, 50.09, 43.77]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([10, 61])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "No Zoom Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_no_zoom_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/3927840167.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([10, 61])

# %%
# Ablation on CIFAR 10 - FGSM

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [60.70, 53.91, 48.21, 38.87]
neurofocus = [49.81, 36.21, 26.55, 18.22]
no_zoom = [38.71, 25.61, 17.76, 12.42]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([10, 61])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "No Zoom Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_no_zoom_pretrained_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/870527793.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([10, 61])

# %%
# Ablation on Stanford Dogs - FGSM

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [8.72, 2.68, 1.76, 1.46]
# neurofocus = []
no_zoom = [7.59, 2.34, 1.6, 1.4]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 15])
plt.plot(training_data, neurozoom, "-s")
# plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "No Zoom Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/921475619.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 15])

# %%
# Ablation on Stanford Dogs - FGSM

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [12.01, 3.60, 2.68, 2.25]
# neurofocus = []
no_zoom = [12.63, 3.95, 2.73, 2.18]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([0, 15])
plt.plot(training_data, neurozoom, "-s")
# plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "No Zoom Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom_pretrained_fgsm.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/3576589948.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([0, 15])

# %%
# Ablation on CIFAR 10 - Gaussian

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [56.30, 55.29, 52.72, 45.93]
neurofocus = [58.21, 57.82, 56.59, 51.57]
no_zoom = [54.51, 53.62, 50.62, 43.82]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([30, 65])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "NeuroFocus Scratch", "No Zoom Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_no_zoom_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/3471397026.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([30, 65])

# %%
# Ablation on CIFAR 10 - FGSM

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [62.54, 61.89, 57.58, 47.36]
neurofocus = [54.15, 53.85, 52.72, 48.97]
no_zoom = [43.18, 42.65, 40.21, 34.08]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([30, 65])
plt.plot(training_data, neurozoom, "-s")
plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "NeuroFocus Pretrained", "No Zoom Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("cifar10_no_zoom_pretrained_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/448093449.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([30, 65])

# %%
# Ablation on Stanford Dogs - Gaussian

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [14.84, 14.49, 12.41, 8]
# neurofocus = []
no_zoom = [13.22, 12.38, 10.23, 6.56]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([6, 22])
plt.plot(training_data, neurozoom, "-s")
# plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Scratch", "No Zoom Scratch"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom_gaussian.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/53963414.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([6, 22])

# %%
# Ablation on Stanford Dogs - Gaussian

epsilon = [0.01, 0.05, 0.1, 0.2]
neurozoom = [20.48, 19.58, 16.25, 10.17]
# neurofocus = []
no_zoom = [21.08, 19.95, 16.53, 9.13]

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern", "DejaVu Serif"],  # cmr10 closely matches LaTeX
    "axes.labelsize": 14,
    "font.size": 14,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.linewidth": 1,
    "lines.markersize": 6,
    "lines.linewidth": 2,
    "legend.frameon": False,
    "legend.handlelength": 2,
})
plt.ylim([6, 22])
plt.plot(training_data, neurozoom, "-s")
# plt.plot(training_data, neurofocus, "-s")
plt.plot(training_data, no_zoom, "-s", color="C3")
plt.xlabel(r"Epsilon")
plt.ylabel("Classification Accuracy (%)")
plt.legend(["NeuroZoom Pretrained", "No Zoom Pretrained"], loc="upper right")
plt.tight_layout()
# plt.savefig("stanford_dogs_no_zoom_gaussian_pretrained.pdf", dpi=300)
plt.show()
# Out:
# /var/folders/t0/9s1kd78j2w76jjypvc2j3x900000gn/T/ipykernel_23617/80520091.py:23: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.ylim([6, 22])
